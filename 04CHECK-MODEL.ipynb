# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl
import warnings
warnings.filterwarnings('ignore')
import sklearn

# %%
name = input("enter name")
company = input("enter company")
year = int(input("Enter Car year"))
km_driven = int(input("Enter Car Driven in KM"))
fuel_type = input("Enter Car Fule Type")
# Out:
# enter name Ford
# enter company Figo
# Enter Car year 2020
# Enter Car Driven in KM 2300
# Enter Car Fule Type Petrol

# %%
data = pd.DataFrame(data =[[name,company,year,km_driven,fuel_type]],columns=["name","company","year","kms_driven","fuel_type"])
data

# %%
pipe = pkl.load(open("CPP.pkl","rb+"))

# %%
pipe.predict(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pipe.predict(data)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:787, in Pipeline.predict(self, X, **params)
#     785 if not _routing_enabled():
#     786     for _, name, transform in self._iter(with_final=False):
# --> 787         Xt = transform.transform(Xt)
#     788     return self.steps[-1][1].predict(Xt, **params)
#     790 # metadata routing enabled
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
# ...

# %%
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1
