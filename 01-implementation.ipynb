# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv("data.csv")
ds
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
ds["name"].unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
ds["company"].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'I', 'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Commercial', 'MARUTI', 'Force', 'Mercedes', 'Land', 'Yamaha',
#        'selling', 'URJENT', 'Swift', 'Used', 'Jaguar', 'Jeep', 'tata',
#        'Sale', 'very', 'Volvo', 'i', '2012', 'Well', 'all', '7', '9',
#        'scratch', 'urgent', 'sell', 'TATA', 'Any', 'Tara'], dtype=object)

# %%
ds["year"].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
ds["Price"].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
ds["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
ds["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
ds["year"].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
ds["year"] = pd.to_numeric(ds["year"],errors='coerce')

# %%
ds["year"].unique()
# Out:
# array([2007., 2006., 2018., 2014., 2015., 2012., 2013., 2016., 2010.,
#        2017., 2008., 2011., 2019., 2009., 2005., 2000.,   nan, 2003.,
#        2004., 1995., 2002., 2001.])

# %%
ds.dropna(subset=["year"],inplace=True)

# %%
ds["year"].unique()
# Out:
# array([2007., 2006., 2018., 2014., 2015., 2012., 2013., 2016., 2010.,
#        2017., 2008., 2011., 2019., 2009., 2005., 2000., 2003., 2004.,
#        1995., 2002., 2001.])

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    float64
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 46.0+ KB

# %%
ds["Price"].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
for i in ds.index:
    price = ds.loc[i,"Price"]
    price = price.replace(",","")
    ds.loc[i,"Price"] =price

# %%
ds["Price"].unique()
# Out:
# array(['80000', '425000', 'Ask For Price', '325000', '575000', '175000',
#        '190000', '830000', '250000', '182000', '315000', '415000',
#        '320000', '1000000', '500000', '350000', '160000', '310000',
#        '75000', '100000', '290000', '95000', '180000', '385000', '105000',
#        '650000', '689999', '448000', '549000', '501000', '489999',
#        '280000', '349999', '284999', '345000', '499999', '235000',
#        '249999', '1475000', '395000', '220000', '170000', '85000',
#        '200000', '570000', '110000', '448999', '1891111', '159500',
#        '344999', '449999', '865000', '699000', '375000', '224999',
#        '1200000', '195000', '351000', '240000', '90000', '155000',
#        '600000', '189500', '210000', '390000', '135000', '1600000',
#        '701000', '265000', '525000', '372000', '635000', '550000',
#        '485000', '329500', '251111', '569999', '69999', '299999',
#        '399999', '450000', '270000', '158400', '179000', '125000',
# ...

# %%
ds["Price"] = pd.to_numeric(ds["Price"],errors='coerce')

# %%
ds["Price"].unique()
# Out:
# array([  80000.,  425000.,      nan,  325000.,  575000.,  175000.,
#         190000.,  830000.,  250000.,  182000.,  315000.,  415000.,
#         320000., 1000000.,  500000.,  350000.,  160000.,  310000.,
#          75000.,  100000.,  290000.,   95000.,  180000.,  385000.,
#         105000.,  650000.,  689999.,  448000.,  549000.,  501000.,
#         489999.,  280000.,  349999.,  284999.,  345000.,  499999.,
#         235000.,  249999., 1475000.,  395000.,  220000.,  170000.,
#          85000.,  200000.,  570000.,  110000.,  448999., 1891111.,
#         159500.,  344999.,  449999.,  865000.,  699000.,  375000.,
#         224999., 1200000.,  195000.,  351000.,  240000.,   90000.,
#         155000.,  600000.,  189500.,  210000.,  390000.,  135000.,
#        1600000.,  701000.,  265000.,  525000.,  372000.,  635000.,
#         550000.,  485000.,  329500.,  251111.,  569999.,   69999.,
#         299999.,  399999.,  450000.,  270000.,  158400.,  179000.,
# ...

# %%
ds.dropna(subset=["Price"],inplace=True)
ds
# Out:
#                                        name    company    year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007.0   80000.0
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006.0  425000.0
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014.0  325000.0
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014.0  575000.0
# 6                                 Ford Figo       Ford  2012.0  175000.0
# ..                                      ...        ...     ...       ...
# 886                    Toyota Corolla Altis     Toyota  2009.0  300000.0
# 888                     Tata Zest XM Diesel       Tata  2018.0  260000.0
# 889                      Mahindra Quanto C8   Mahindra  2013.0  390000.0
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014.0  180000.0
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014.0  160000.0
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    float64
#  3   Price       819 non-null    float64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 44.8+ KB

# %%
ds["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
ds["kms_driven"].unique()

ds["kms_driven"] = ds["kms_driven"].str.replace(",","") #remove ,
ds["kms_driven"] = ds["kms_driven"].str.replace(" kms","")# remove kms
ds["kms_driven"].unique()

ds["kms_driven"] = pd.to_numeric(ds["kms_driven"],errors='coerce') #convert data type
# Out:
# 0       45000.0
# 1          40.0
# 3       28000.0
# 4       36000.0
# 6       41000.0
#          ...
# 886    132000.0
# 888     27000.0
# 889     40000.0
# 890         NaN
# 891         NaN
# Name: kms_driven, Length: 819, dtype: float64

# %%
ds.dropna(subset=["kms_driven"],inplace=True)

# %%
ds["kms_driven"]
# Out:
# 0       45000.0
# 1          40.0
# 3       28000.0
# 4       36000.0
# 6       41000.0
#          ...
# 883     50000.0
# 885     30000.0
# 886    132000.0
# 888     27000.0
# 889     40000.0
# Name: kms_driven, Length: 817, dtype: float64

# %%
ds
# Out:
#                                        name   company    year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007.0   80000.0
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006.0  425000.0
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014.0  325000.0
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014.0  575000.0
# 6                                 Ford Figo      Ford  2012.0  175000.0
# ..                                      ...       ...     ...       ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011.0  270000.0
# 885               Tata Indica V2 DLE BS III      Tata  2009.0  110000.0
# 886                    Toyota Corolla Altis    Toyota  2009.0  300000.0
# 888                     Tata Zest XM Diesel      Tata  2018.0  260000.0
# 889                      Mahindra Quanto C8  Mahindra  2013.0  390000.0
#
#      kms_driven fuel_type
# 0       45000.0    Petrol
# 1          40.0    Diesel
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    float64
#  3   Price       817 non-null    float64
#  4   kms_driven  817 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 44.7+ KB

# %%
ds["name"].unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Maruti Suzuki Alto 800 Vxi', 'Hyundai i20 Sportz 1.2',
#        'Maruti Suzuki Alto 800 Lx', 'Maruti Suzuki Vitara Brezza ZDi',
#        'Maruti Suzuki Alto LX', 'Mahindra Bolero DI',
#        'Maruti Suzuki Swift Dzire ZDi', 'Mahindra Scorpio S10 4WD',
#        'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
ds["company"].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
for i in ds.index:
    company  = ds.loc[i,"company"]
    name = ds.loc[i,"name"]
    name = name.replace(company,"")
    ds.loc[i,"name"] = name
ds["name"] = ds["name"].str.strip()
ds["name"].unique()
# Out:
# array(['Santro Xing XO eRLX Euro III', 'Jeep CL550 MDI',
#        'Grand i10 Magna 1.2 Kappa VTVT', 'EcoSport Titanium 1.5L TDCi',
#        'Figo', 'Eon', 'EcoSport Ambiente 1.5L TDCi',
#        'Suzuki Alto K10 VXi AMT', 'Fabia Classic 1.2 MPI',
#        'Suzuki Stingray VXi', 'Elite i20 Magna 1.2', 'Scorpio SLE BS IV',
#        'A8', 'Q7', 'Scorpio S10', 'Suzuki Alto 800',
#        'Suzuki Alto 800 Vxi', 'i20 Sportz 1.2', 'Suzuki Alto 800 Lx',
#        'Suzuki Vitara Brezza ZDi', 'Suzuki Alto LX', 'Bolero DI',
#        'Suzuki Swift Dzire ZDi', 'Scorpio S10 4WD',
#        'Suzuki Swift Vdi BSIII', 'Suzuki Wagon R VXi BS III',
#        'Suzuki Wagon R VXi Minor', 'Innova 2.0 G 8 STR BS IV',
#        'Lodgy 85 PS RXL', 'Yeti Ambition 2.0 TDI CR 4x2',
#        'Suzuki Baleno Delta 1.2', 'Duster 110 PS RxZ Diesel Plus',
#        'Duster 85 PS RxE Diesel', 'City 1.5 S MT', 'Suzuki Dzire',
#        'Amaze', 'Amaze 1.5 SX i DTEC', 'City', 'Redi GO S',
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    float64
#  3   Price       817 non-null    float64
#  4   kms_driven  817 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 77.0+ KB

# %%
ds.dropna(inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    float64
#  3   Price       816 non-null    float64
#  4   kms_driven  816 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 44.6+ KB

# %%
ds["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
ds.duplicated().value_counts()
# Out:
# False    724
# True      92
# Name: count, dtype: int64

# %%
ds.drop_duplicates(inplace=True)

# %%
ds.duplicated().value_counts()
# Out:
# False    724
# Name: count, dtype: int64

# %%
ds["Price"].min()
# Out:
# 30000.0

# %%
ds["Price"].max()
# Out:
# 8500003.0

# %%
ds["kms_driven"].min()
# Out:
# 0.0

# %%
ds["kms_driven"].max()
# Out:
# 400000.0

# %%
ds[ds["kms_driven"]<100]
# Out:
#                                 name   company    year      Price  kms_driven  \
# 1                     Jeep CL550 MDI  Mahindra  2006.0   425000.0        40.0
# 215                  Jeep MM 550 XDB  Mahindra  2019.0   390000.0        60.0
# 220                   Jeep CL550 MDI  Mahindra  2019.0   379000.0         0.0
# 302   Suzuki Swift VXi 1.2 ABS BS IV    Maruti  2019.0   610000.0        73.0
# 387      Innova 2.5 E MS 7 STR BS IV    Toyota  2012.0   770000.0         0.0
# 470      Suzuki Swift Dzire Tour VXi    Maruti  2011.0   230000.0        65.0
# 702             Figo Petrol Titanium      Ford  2019.0   525000.0         0.0
# 721  Suzuki Zen Estilo LXI Green CNG    Maruti  2009.0   125000.0         0.0
# 738                     Creta 1.6 SX   Hyundai  2019.0  1200000.0         0.0
# 762                Tiago Revotorq XZ      Tata  2019.0   568500.0         0.0
#
#     fuel_type
# 1      Diesel
# 215    Diesel
# 220    Diesel
# 302    Petrol
# 387    Diesel
# 470    Petrol
# ...

# %%
ds = ds[ds["Price"]<8500000]

# %%
ds["Price"].max()
# Out:
# 3100000.0

# %%
ds = ds[ds["kms_driven"]>500]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 709 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        709 non-null    object
#  1   company     709 non-null    object
#  2   year        709 non-null    float64
#  3   Price       709 non-null    float64
#  4   kms_driven  709 non-null    float64
#  5   fuel_type   709 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 38.8+ KB

# %%
ds.reset_index(drop=True,inplace= True)
ds
# Out:
#                                name   company    year     Price  kms_driven  \
# 0      Santro Xing XO eRLX Euro III   Hyundai  2007.0   80000.0     45000.0
# 1    Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014.0  325000.0     28000.0
# 2       EcoSport Titanium 1.5L TDCi      Ford  2014.0  575000.0     36000.0
# 3                              Figo      Ford  2012.0  175000.0     41000.0
# 4                               Eon   Hyundai  2013.0  190000.0     25000.0
# ..                              ...       ...     ...       ...         ...
# 704             Suzuki Ritz VXI ABS    Maruti  2011.0  270000.0     50000.0
# 705            Indica V2 DLE BS III      Tata  2009.0  110000.0     30000.0
# 706                   Corolla Altis    Toyota  2009.0  300000.0    132000.0
# 707                  Zest XM Diesel      Tata  2018.0  260000.0     27000.0
# 708                       Quanto C8  Mahindra  2013.0  390000.0     40000.0
#
#     fuel_type
# 0      Petrol
# 1      Petrol
# ...

# %%
ds.to_csv("clean_data.csv")
